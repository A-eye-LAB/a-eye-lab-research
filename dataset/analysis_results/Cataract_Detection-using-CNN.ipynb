# %%
import sys

sys.path.append("../")

from utils.analysis_utils import get_all_paths, get_all_image_paths, get_image_w_h, get_stats, count_files, count_formats, count_image_sizes, show_random_image

# %%
root_dir = "../data/Cataract_Detection-using-CNN"

# %%
# count files

all_paths = get_all_paths(root_dir+"/*")
count_files(all_paths)
# Out:
# ../data/Cataract_Detection-using-CNN/0 : 5154
# ../data/Cataract_Detection-using-CNN/1 : 4514

# %%
# sample image (cataract)
show_random_image(root_dir+"/1")
# Out:
# cat_0_7219.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=269x188>

# %%
# sample image (normal)
show_random_image(root_dir+"/0")
# Out:
# cat_0_9019.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=273x185>

# %%
all_image_paths = get_all_image_paths(all_paths)

# %%
# count formats

count_formats(all_image_paths)
# Out:
# Counter({'jpg': 9668})

# %%
all_widths, all_heights = get_image_w_h(all_image_paths)

# %%
# count image sizes

count_image_sizes(all_widths, all_heights)
# Out:
# Counter({(275, 183): 1248,
#          (259, 194): 628,
#          (300, 168): 508,
#          (272, 185): 208,
#          (290, 174): 183,
#          (277, 182): 135,
#          (286, 176): 126,
#          (276, 182): 117,
#          (278, 181): 114,
#          (276, 183): 108,
#          (273, 185): 101,
#          (251, 201): 100,
#          (252, 200): 99,
#          (305, 165): 99,
#          (263, 192): 96,
#          (225, 225): 94,
#          (255, 198): 92,
#          (281, 179): 87,
#          (310, 163): 83,
#          (258, 196): 80,
#          (194, 259): 76,
#          (220, 168): 75,
#          (250, 188): 72,
#          (256, 192): 70,
#          (283, 178): 67,
#          (264, 191): 67,
#          (265, 190): 66,
#          (318, 159): 65,
#          (302, 167): 65,
#          (275, 184): 64,
#          (250, 202): 64,
#          (236, 213): 63,
#          (279, 180): 63,
#          (271, 186): 63,
#          (254, 198): 60,
#          (229, 220): 60,
#          (284, 177): 58,
#          (260, 194): 58,
#          (237, 212): 57,
#          (266, 189): 57,
#          (272, 186): 57,
#          (384, 256): 49,
#          (400, 320): 48,
#          (246, 205): 47,
#          (340, 148): 45,
#          (650, 350): 45,
#          (269, 188): 44,
#          (279, 181): 42,
#          (344, 248): 42,
#          (259, 195): 41,
#          (306, 165): 38,
#          (248, 203): 38,
#          (339, 149): 37,
#          (350, 231): 37,
#          (300, 240): 37,
#          (330, 153): 36,
#          (253, 199): 36,
#          (322, 156): 36,
#          (240, 210): 36,
#          (220, 157): 35,
#          (214, 235): 34,
#          (243, 207): 34,
#          (2000, 1312): 34,
#          (297, 170): 33,
#          (260, 173): 33,
#          (168, 300): 33,
#          (249, 203): 32,
#          (240, 150): 32,
#          (274, 184): 32,
#          (4160, 3120): 32,
#          (287, 176): 31,
#          (294, 171): 31,
#          (282, 179): 31,
#          (183, 275): 31,
#          (268, 188): 30,
#          (226, 223): 30,
#          (261, 193): 30,
#          (263, 191): 30,
#          (624, 351): 30,
#          (700, 466): 30,
#          (493, 335): 30,
#          (1837, 1224): 30,
#          (220, 147): 29,
#          (267, 189): 29,
#          (220, 165): 29,
#          (252, 185): 29,
#          (190, 151): 28,
#          (297, 169): 28,
#          (280, 180): 28,
#          (273, 184): 27,
#          (299, 168): 27,
#          (736, 552): 27,
#          (357, 238): 27,
#          (200, 200): 26,
#          (210, 240): 25,
#          (256, 197): 25,
#          (249, 202): 25,
#          (243, 208): 24,
#          (219, 230): 22,
#          (264, 247): 21,
#          (368, 242): 21,
#          (340, 221): 21,
#          (344, 236): 21,
#          (347, 247): 21,
#          (354, 238): 21,
#          (330, 249): 21,
#          (334, 225): 21,
#          (244, 238): 21,
#          (346, 235): 21,
#          (335, 221): 21,
#          (369, 257): 21,
#          (390, 251): 21,
#          (356, 246): 21,
#          (215, 229): 21,
#          (377, 238): 21,
#          (248, 243): 20,
#          (362, 242): 20,
#          (355, 316): 20,
#          (342, 247): 20,
#          (357, 239): 20,
#          (383, 265): 20,
#          (372, 263): 20,
#          (276, 266): 20,
#          (261, 251): 20,
#          (267, 264): 20,
#          (237, 245): 20,
#          (287, 236): 20,
#          (362, 260): 20,
#          (371, 236): 20,
#          (363, 251): 20,
#          (336, 226): 20,
#          (255, 246): 20,
#          (358, 223): 19,
#          (269, 187): 19,
#          (300, 180): 19,
#          (355, 238): 19,
#          (363, 239): 19,
#          (379, 262): 19,
#          (253, 239): 19,
#          (344, 251): 19,
#          (338, 227): 19,
#          (365, 239): 19,
#          (359, 238): 19,
#          (244, 207): 19,
#          (356, 247): 19,
#          (272, 238): 19,
#          (228, 227): 19,
#          (2625, 2357): 19,
#          (328, 228): 19,
#          (365, 240): 19,
#          (293, 172): 18,
#          (270, 187): 18,
#          (390, 275): 18,
#          (344, 227): 18,
#          (298, 243): 18,
#          (261, 248): 18,
#          (240, 227): 18,
#          (348, 244): 18,
#          (327, 209): 18,
#          (267, 275): 18,
#          (318, 214): 18,
#          (453, 302): 18,
#          (335, 232): 18,
#          (367, 249): 18,
#          (362, 236): 18,
#          (367, 243): 18,
#          (336, 224): 18,
#          (400, 250): 18,
#          (367, 224): 18,
#          (380, 263): 18,
#          (269, 257): 18,
#          (250, 138): 17,
#          (350, 368): 17,
#          (359, 250): 17,
#          (256, 237): 17,
#          (248, 240): 17,
#          (233, 234): 17,
#          (225, 245): 17,
#          (389, 271): 17,
#          (230, 220): 17,
#          (800, 600): 17,
#          (500, 290): 16,
#          (454, 605): 16,
#          (530, 232): 16,
#          (233, 216): 16,
#          (244, 240): 16,
#          (202, 226): 16,
#          (523, 389): 16,
#          (366, 244): 16,
#          (1200, 888): 16,
#          (242, 208): 15,
#          (596, 396): 15,
#          (254, 278): 15,
#          (1024, 615): 15,
#          (250, 201): 14,
#          (889, 607): 14,
#          (223, 226): 14,
#          (300, 150): 14,
#          (1186, 820): 14,
#          (258, 195): 14,
#          (250, 250): 14,
#          (640, 434): 13,
#          (160, 131): 13,
#          (274, 154): 13,
#          (262, 192): 13,
#          (174, 114): 13,
#          (252, 262): 13,
#          (1600, 1067): 13,
#          (300, 305): 13,
#          (210, 200): 13,
#          (395, 400): 13,
#          (212, 212): 11,
#          (773, 478): 11,
#          (242, 209): 11,
#          (986, 555): 11,
#          (320, 320): 11,
#          (289, 174): 10,
#          (220, 229): 10,
#          (239, 210): 10,
#          (768, 464): 8,
#          (252, 256): 6,
#          (198, 208): 1})

# %%
# image size statistics

print('width')
get_stats(all_widths)
print('height')
get_stats(all_heights)
# Out:
# width
# min: 160
# max: 4160
# mean: 325.8
# median: 275
# mode: 275 (13.6 %)
# height
# min: 114
# max: 3120
# mean: 231.0
# median: 190
# mode: 183 (14.0 %)
