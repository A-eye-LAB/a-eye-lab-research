# %%
import sys

sys.path.append("../")

from analysis_utils import get_all_paths, get_all_image_paths, get_image_w_h, get_stats, count_files, count_formats, count_image_sizes, show_random_image

# %%
root_dir = "../data/kaggle_cataract_kersh"

# %%
# count files

all_paths = get_all_paths(root_dir+"/*")
count_files(all_paths)
# Out:
# ../data/kaggle_cataract_kersh/0 : 317
# ../data/kaggle_cataract_kersh/1 : 355

# %%
# sample image (cataract)
show_random_image(root_dir+"/1")
# Out:
# Cataract (238).png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=148x109>

# %%
# sample image (normal)
show_random_image(root_dir+"/0")
# Out:
# Normal (245).png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=376x327>

# %%
all_image_paths = get_all_image_paths(all_paths)

# %%
# count formats

count_formats(all_image_paths)
# Out:
# Counter({'png': 617, 'jpg': 54, 'webp': 1})

# %%
all_widths, all_heights = get_image_w_h(all_image_paths)

# %%
# count image sizes

count_image_sizes(all_widths, all_heights)
# Out:
# Counter({(546, 494): 7,
#          (263, 194): 7,
#          (431, 381): 7,
#          (489, 329): 7,
#          (931, 776): 6,
#          (307, 205): 5,
#          (340, 266): 5,
#          (720, 644): 5,
#          (68, 58): 4,
#          (37, 26): 4,
#          (35, 26): 4,
#          (32, 27): 4,
#          (1029, 805): 4,
#          (381, 280): 4,
#          (148, 109): 4,
#          (147, 118): 4,
#          (222, 169): 4,
#          (308, 282): 4,
#          (494, 479): 4,
#          (669, 476): 4,
#          (306, 195): 4,
#          (634, 578): 4,
#          (246, 223): 4,
#          (1266, 1010): 3,
#          (261, 201): 3,
#          (73, 57): 3,
#          (23, 19): 3,
#          (21, 17): 3,
#          (76, 63): 3,
#          (49, 40): 3,
#          (255, 210): 3,
#          (135, 103): 3,
#          (219, 144): 3,
#          (605, 497): 3,
#          (246, 195): 3,
#          (180, 163): 3,
#          (780, 656): 3,
#          (171, 118): 3,
#          (154, 129): 3,
#          (188, 186): 3,
#          (159, 160): 3,
#          (88, 70): 3,
#          (503, 404): 3,
#          (494, 478): 3,
#          (356, 332): 3,
#          (172, 153): 3,
#          (409, 339): 2,
#          (47, 38): 2,
#          (655, 515): 2,
#          (32, 20): 2,
#          (132, 113): 2,
#          (85, 74): 2,
#          (77, 54): 2,
#          (624, 553): 2,
#          (145, 119): 2,
#          (424, 381): 2,
#          (175, 139): 2,
#          (197, 167): 2,
#          (60, 49): 2,
#          (41, 29): 2,
#          (122, 96): 2,
#          (20, 14): 2,
#          (831, 759): 2,
#          (50, 40): 2,
#          (73, 55): 2,
#          (693, 623): 2,
#          (101, 67): 2,
#          (57, 41): 2,
#          (65, 55): 2,
#          (164, 94): 2,
#          (70, 54): 2,
#          (36, 31): 2,
#          (81, 54): 2,
#          (70, 55): 2,
#          (73, 54): 2,
#          (45, 33): 2,
#          (55, 46): 2,
#          (136, 107): 2,
#          (45, 36): 2,
#          (579, 470): 2,
#          (65, 42): 2,
#          (43, 37): 2,
#          (67, 56): 2,
#          (57, 28): 2,
#          (54, 43): 2,
#          (732, 704): 2,
#          (1183, 797): 2,
#          (52, 45): 2,
#          (75, 61): 2,
#          (87, 74): 2,
#          (180, 147): 2,
#          (714, 627): 2,
#          (32, 22): 2,
#          (318, 284): 2,
#          (121, 95): 2,
#          (308, 294): 2,
#          (313, 293): 2,
#          (1159, 1102): 2,
#          (422, 340): 2,
#          (494, 485): 2,
#          (508, 328): 2,
#          (606, 506): 2,
#          (511, 412): 2,
#          (576, 527): 2,
#          (294, 250): 2,
#          (987, 739): 2,
#          (640, 480): 2,
#          (230, 195): 2,
#          (113, 94): 2,
#          (423, 347): 2,
#          (310, 312): 2,
#          (335, 234): 2,
#          (297, 259): 2,
#          (149, 126): 2,
#          (153, 127): 2,
#          (219, 145): 2,
#          (190, 142): 2,
#          (389, 355): 2,
#          (210, 199): 2,
#          (139, 92): 2,
#          (494, 355): 2,
#          (639, 480): 2,
#          (259, 199): 2,
#          (600, 515): 2,
#          (336, 227): 2,
#          (213, 175): 2,
#          (106, 70): 2,
#          (190, 164): 2,
#          (171, 213): 2,
#          (581, 525): 2,
#          (407, 298): 2,
#          (494, 466): 2,
#          (327, 266): 2,
#          (240, 201): 2,
#          (233, 219): 2,
#          (248, 210): 1,
#          (73, 61): 1,
#          (20, 13): 1,
#          (83, 58): 1,
#          (610, 478): 1,
#          (77, 50): 1,
#          (41, 26): 1,
#          (21, 16): 1,
#          (103, 85): 1,
#          (67, 61): 1,
#          (76, 57): 1,
#          (124, 72): 1,
#          (29, 23): 1,
#          (26, 16): 1,
#          (30, 25): 1,
#          (111, 92): 1,
#          (73, 50): 1,
#          (154, 119): 1,
#          (43, 32): 1,
#          (66, 69): 1,
#          (1006, 870): 1,
#          (209, 173): 1,
#          (879, 758): 1,
#          (44, 32): 1,
#          (186, 153): 1,
#          (23, 14): 1,
#          (312, 273): 1,
#          (49, 34): 1,
#          (77, 49): 1,
#          (27, 16): 1,
#          (56, 38): 1,
#          (64, 47): 1,
#          (49, 47): 1,
#          (22, 18): 1,
#          (66, 57): 1,
#          (623, 492): 1,
#          (55, 43): 1,
#          (135, 92): 1,
#          (74, 62): 1,
#          (473, 392): 1,
#          (61, 36): 1,
#          (156, 117): 1,
#          (83, 64): 1,
#          (59, 36): 1,
#          (165, 127): 1,
#          (74, 53): 1,
#          (367, 289): 1,
#          (550, 427): 1,
#          (1828, 1502): 1,
#          (231, 201): 1,
#          (135, 117): 1,
#          (26, 18): 1,
#          (59, 43): 1,
#          (32, 25): 1,
#          (34, 29): 1,
#          (13, 9): 1,
#          (22, 14): 1,
#          (142, 112): 1,
#          (23, 21): 1,
#          (257, 204): 1,
#          (45, 34): 1,
#          (22, 16): 1,
#          (99, 70): 1,
#          (207, 195): 1,
#          (293, 234): 1,
#          (39, 32): 1,
#          (40, 34): 1,
#          (32, 21): 1,
#          (155, 118): 1,
#          (76, 61): 1,
#          (23, 16): 1,
#          (22, 17): 1,
#          (78, 72): 1,
#          (41, 34): 1,
#          (249, 210): 1,
#          (150, 114): 1,
#          (236, 197): 1,
#          (45, 35): 1,
#          (277, 242): 1,
#          (95, 58): 1,
#          (42, 34): 1,
#          (74, 51): 1,
#          (476, 410): 1,
#          (1372, 1157): 1,
#          (16, 11): 1,
#          (175, 104): 1,
#          (154, 145): 1,
#          (79, 53): 1,
#          (38, 29): 1,
#          (439, 407): 1,
#          (264, 181): 1,
#          (26, 19): 1,
#          (97, 84): 1,
#          (77, 57): 1,
#          (94, 66): 1,
#          (1088, 856): 1,
#          (47, 35): 1,
#          (15, 10): 1,
#          (44, 35): 1,
#          (340, 263): 1,
#          (87, 63): 1,
#          (1198, 994): 1,
#          (79, 71): 1,
#          (44, 34): 1,
#          (17, 13): 1,
#          (303, 239): 1,
#          (30, 24): 1,
#          (34, 21): 1,
#          (373, 351): 1,
#          (104, 62): 1,
#          (74, 58): 1,
#          (83, 71): 1,
#          (69, 55): 1,
#          (152, 120): 1,
#          (1087, 856): 1,
#          (126, 107): 1,
#          (78, 47): 1,
#          (842, 743): 1,
#          (320, 263): 1,
#          (73, 56): 1,
#          (262, 201): 1,
#          (29, 20): 1,
#          (218, 167): 1,
#          (359, 291): 1,
#          (165, 100): 1,
#          (25, 19): 1,
#          (81, 69): 1,
#          (448, 429): 1,
#          (506, 390): 1,
#          (422, 286): 1,
#          (32, 24): 1,
#          (88, 68): 1,
#          (425, 381): 1,
#          (53, 34): 1,
#          (133, 117): 1,
#          (137, 90): 1,
#          (25, 18): 1,
#          (165, 139): 1,
#          (26, 17): 1,
#          (38, 27): 1,
#          (376, 327): 1,
#          (405, 352): 1,
#          (204, 149): 1,
#          (109, 91): 1,
#          (157, 121): 1,
#          (39, 28): 1,
#          (60, 52): 1,
#          (35, 22): 1,
#          (82, 71): 1,
#          (89, 63): 1,
#          (62, 33): 1,
#          (324, 286): 1,
#          (58, 37): 1,
#          (63, 53): 1,
#          (61, 43): 1,
#          (40, 26): 1,
#          (298, 273): 1,
#          (188, 171): 1,
#          (49, 38): 1,
#          (24, 18): 1,
#          (51, 42): 1,
#          (63, 39): 1,
#          (56, 34): 1,
#          (82, 66): 1,
#          (473, 306): 1,
#          (244, 215): 1,
#          (72, 59): 1,
#          (523, 414): 1,
#          (86, 74): 1,
#          (64, 41): 1,
#          (42, 32): 1,
#          (19, 16): 1,
#          (69, 62): 1,
#          (176, 160): 1,
#          (28, 20): 1,
#          (91, 84): 1,
#          (341, 310): 1,
#          (56, 43): 1,
#          (122, 85): 1,
#          (325, 281): 1,
#          (188, 119): 1,
#          (256, 225): 1,
#          (98, 64): 1,
#          (52, 26): 1,
#          (414, 354): 1,
#          (33, 15): 1,
#          (89, 83): 1,
#          (33, 27): 1,
#          (121, 104): 1,
#          (417, 408): 1,
#          (29, 27): 1,
#          (279, 219): 1,
#          (330, 240): 1,
#          (503, 414): 1,
#          (350, 273): 1,
#          (1043, 898): 1,
#          (223, 169): 1,
#          (202, 173): 1,
#          (254, 233): 1,
#          (647, 616): 1,
#          (223, 190): 1,
#          (604, 507): 1,
#          (624, 459): 1,
#          (628, 488): 1,
#          (306, 289): 1,
#          (292, 261): 1,
#          (819, 750): 1,
#          (180, 148): 1,
#          (618, 496): 1,
#          (273, 239): 1,
#          (230, 178): 1,
#          (95, 81): 1,
#          (334, 252): 1,
#          (119, 98): 1,
#          (635, 483): 1,
#          (157, 126): 1,
#          (53, 51): 1,
#          (1200, 859): 1,
#          (401, 332): 1,
#          (315, 241): 1,
#          (150, 125): 1,
#          (258, 171): 1,
#          (206, 155): 1,
#          (288, 266): 1,
#          (465, 312): 1,
#          (476, 434): 1,
#          (589, 521): 1,
#          (350, 381): 1,
#          (277, 182): 1,
#          (315, 273): 1,
#          (203, 176): 1,
#          (150, 150): 1,
#          (2505, 2387): 1,
#          (735, 615): 1,
#          (327, 296): 1,
#          (87, 68): 1,
#          (262, 225): 1,
#          (134, 112): 1,
#          (231, 156): 1,
#          (597, 434): 1,
#          (611, 502): 1,
#          (248, 196): 1,
#          (67, 62): 1,
#          (1059, 938): 1,
#          (644, 476): 1,
#          (617, 386): 1,
#          (189, 182): 1,
#          (2604, 2306): 1,
#          (336, 267): 1,
#          (324, 305): 1,
#          (210, 200): 1,
#          (263, 234): 1,
#          (630, 473): 1,
#          (213, 198): 1,
#          (326, 264): 1,
#          (76, 59): 1,
#          (35, 137): 1,
#          (275, 206): 1,
#          (149, 139): 1,
#          (286, 265): 1,
#          (162, 132): 1,
#          (317, 295): 1,
#          (384, 256): 1,
#          (220, 153): 1,
#          (368, 352): 1,
#          (113, 103): 1,
#          (423, 358): 1,
#          (142, 101): 1,
#          (532, 540): 1,
#          (264, 154): 1,
#          (523, 389): 1,
#          (218, 136): 1,
#          (268, 210): 1,
#          (759, 687): 1,
#          (259, 204): 1,
#          (539, 404): 1,
#          (180, 132): 1,
#          (66, 56): 1,
#          (187, 154): 1,
#          (723, 633): 1,
#          (593, 483): 1,
#          (107, 80): 1,
#          (336, 306): 1,
#          (128, 108): 1,
#          (503, 503): 1,
#          (108, 78): 1,
#          (348, 266): 1,
#          (240, 181): 1,
#          (146, 111): 1,
#          (87, 76): 1,
#          (430, 340): 1,
#          (1600, 1068): 1,
#          (347, 318): 1,
#          (304, 193): 1,
#          (443, 296): 1,
#          (410, 387): 1,
#          (441, 389): 1,
#          (266, 206): 1,
#          (51, 40): 1,
#          (225, 178): 1,
#          (366, 244): 1,
#          (128, 105): 1,
#          (590, 515): 1,
#          (488, 381): 1,
#          (521, 461): 1,
#          (351, 234): 1,
#          (181, 151): 1,
#          (737, 416): 1,
#          (682, 550): 1,
#          (134, 146): 1,
#          (75, 50): 1,
#          (637, 482): 1,
#          (87, 79): 1,
#          (178, 168): 1,
#          (294, 238): 1,
#          (554, 554): 1})

# %%
# image size statistics

print('width')
get_stats(all_widths)
print('height')
get_stats(all_heights)
# Out:
# width
# min: 13
# max: 2604
# mean: 294.2
# median: 210
# mode: 494 (1.9 %)
# height
# min: 9
# max: 2387
# mean: 242.0
# median: 169
# mode: 381 (1.8 %)
