# %%
import sys

sys.path.append("../")

from analysis_utils import get_all_paths, get_all_image_paths, get_image_w_h, get_stats, count_files, count_formats, count_image_sizes, show_random_image

# %%
root_dir = "../data/kaggle_cataract_nand"

# %%
# count files

all_paths = get_all_paths(root_dir+"/*")
count_files(all_paths)
# Out:
# ../data/kaggle_cataract_nand/0 : 306
# ../data/kaggle_cataract_nand/1 : 304

# %%
# sample image (cataract)
show_random_image(root_dir+"/1")
# Out:
# image_165.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=594x308>

# %%
# sample image (normal)
show_random_image(root_dir+"/0")
# Out:
# image_41.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=80x45>

# %%
all_image_paths = get_all_image_paths(all_paths)

# %%
# count formats

count_formats(all_image_paths)
# Out:
# Counter({'png': 610})

# %%
all_widths, all_heights = get_image_w_h(all_image_paths)

# %%
# count image sizes

count_image_sizes(all_widths, all_heights)
# Out:
# Counter({(1000, 667): 16,
#          (1600, 1067): 8,
#          (493, 335): 8,
#          (999, 650): 7,
#          (1500, 1001): 7,
#          (1091, 727): 7,
#          (1543, 1120): 6,
#          (1200, 800): 6,
#          (800, 600): 5,
#          (597, 313): 5,
#          (356, 179): 5,
#          (611, 305): 5,
#          (852, 480): 4,
#          (1920, 1440): 4,
#          (1280, 853): 4,
#          (900, 368): 4,
#          (250, 167): 4,
#          (1920, 1080): 4,
#          (1000, 1000): 4,
#          (600, 391): 4,
#          (241, 183): 4,
#          (1500, 1000): 4,
#          (800, 539): 4,
#          (615, 409): 4,
#          (425, 282): 3,
#          (1000, 587): 3,
#          (3975, 2549): 3,
#          (1920, 1280): 3,
#          (157, 240): 3,
#          (800, 530): 3,
#          (594, 308): 3,
#          (1280, 800): 3,
#          (250, 175): 3,
#          (1186, 820): 3,
#          (632, 319): 3,
#          (474, 358): 3,
#          (400, 260): 3,
#          (557, 415): 3,
#          (200, 136): 3,
#          (500, 500): 3,
#          (600, 330): 3,
#          (352, 231): 3,
#          (850, 350): 3,
#          (400, 224): 3,
#          (800, 554): 3,
#          (284, 313): 2,
#          (4144, 2480): 2,
#          (184, 185): 2,
#          (311, 235): 2,
#          (208, 157): 2,
#          (250, 185): 2,
#          (2098, 1392): 2,
#          (228, 184): 2,
#          (273, 341): 2,
#          (174, 132): 2,
#          (150, 150): 2,
#          (5739, 3826): 2,
#          (1200, 630): 2,
#          (227, 185): 2,
#          (450, 271): 2,
#          (334, 301): 2,
#          (1327, 885): 2,
#          (230, 184): 2,
#          (127, 100): 2,
#          (117, 123): 2,
#          (312, 381): 2,
#          (119, 119): 2,
#          (274, 236): 2,
#          (311, 236): 2,
#          (285, 200): 2,
#          (312, 292): 2,
#          (251, 249): 2,
#          (400, 300): 2,
#          (320, 301): 2,
#          (161, 125): 2,
#          (195, 204): 2,
#          (69, 49): 2,
#          (1024, 683): 2,
#          (579, 449): 2,
#          (2272, 1476): 2,
#          (2198, 1460): 2,
#          (242, 171): 2,
#          (640, 427): 2,
#          (161, 85): 2,
#          (300, 300): 2,
#          (176, 85): 2,
#          (200, 132): 2,
#          (1024, 415): 2,
#          (700, 466): 2,
#          (646, 431): 2,
#          (564, 404): 2,
#          (510, 340): 2,
#          (1837, 1224): 2,
#          (500, 309): 2,
#          (920, 613): 2,
#          (980, 465): 2,
#          (321, 307): 2,
#          (2250, 1500): 2,
#          (1024, 716): 2,
#          (640, 478): 2,
#          (3684, 2528): 2,
#          (750, 500): 2,
#          (1000, 646): 2,
#          (165, 116): 2,
#          (461, 285): 2,
#          (246, 179): 2,
#          (701, 470): 2,
#          (4160, 3120): 2,
#          (640, 640): 2,
#          (1805, 1200): 2,
#          (768, 320): 2,
#          (880, 587): 2,
#          (1600, 1074): 2,
#          (960, 393): 2,
#          (311, 168): 1,
#          (236, 154): 1,
#          (506, 300): 1,
#          (509, 339): 1,
#          (1024, 576): 1,
#          (303, 169): 1,
#          (1024, 682): 1,
#          (630, 420): 1,
#          (760, 506): 1,
#          (1600, 951): 1,
#          (104, 93): 1,
#          (218, 171): 1,
#          (256, 163): 1,
#          (740, 396): 1,
#          (270, 251): 1,
#          (500, 333): 1,
#          (600, 323): 1,
#          (843, 947): 1,
#          (595, 370): 1,
#          (250, 250): 1,
#          (120, 72): 1,
#          (116, 69): 1,
#          (165, 144): 1,
#          (824, 530): 1,
#          (205, 115): 1,
#          (1247, 933): 1,
#          (774, 1032): 1,
#          (355, 291): 1,
#          (600, 399): 1,
#          (978, 774): 1,
#          (1024, 745): 1,
#          (386, 254): 1,
#          (296, 129): 1,
#          (1630, 1137): 1,
#          (1110, 833): 1,
#          (1024, 697): 1,
#          (850, 606): 1,
#          (1140, 655): 1,
#          (246, 241): 1,
#          (900, 705): 1,
#          (388, 220): 1,
#          (4066, 2287): 1,
#          (235, 129): 1,
#          (294, 185): 1,
#          (173, 117): 1,
#          (3333, 1975): 1,
#          (96, 48): 1,
#          (165, 120): 1,
#          (612, 448): 1,
#          (239, 229): 1,
#          (262, 124): 1,
#          (318, 172): 1,
#          (1032, 774): 1,
#          (1892, 1125): 1,
#          (107, 68): 1,
#          (109, 65): 1,
#          (220, 109): 1,
#          (113, 62): 1,
#          (118, 58): 1,
#          (122, 72): 1,
#          (183, 86): 1,
#          (590, 350): 1,
#          (1079, 768): 1,
#          (147, 79): 1,
#          (87, 99): 1,
#          (160, 109): 1,
#          (222, 86): 1,
#          (147, 84): 1,
#          (268, 170): 1,
#          (162, 85): 1,
#          (57, 42): 1,
#          (77, 59): 1,
#          (296, 254): 1,
#          (139, 100): 1,
#          (411, 283): 1,
#          (1300, 1139): 1,
#          (322, 186): 1,
#          (220, 146): 1,
#          (94, 55): 1,
#          (312, 191): 1,
#          (70, 54): 1,
#          (191, 94): 1,
#          (342, 170): 1,
#          (197, 79): 1,
#          (162, 136): 1,
#          (200, 110): 1,
#          (131, 68): 1,
#          (69, 65): 1,
#          (351, 186): 1,
#          (1024, 728): 1,
#          (900, 626): 1,
#          (302, 384): 1,
#          (164, 90): 1,
#          (158, 84): 1,
#          (54, 39): 1,
#          (375, 223): 1,
#          (79, 40): 1,
#          (897, 758): 1,
#          (620, 330): 1,
#          (266, 218): 1,
#          (4220, 2556): 1,
#          (277, 194): 1,
#          (350, 191): 1,
#          (381, 311): 1,
#          (71, 46): 1,
#          (84, 51): 1,
#          (322, 263): 1,
#          (292, 234): 1,
#          (138, 66): 1,
#          (139, 84): 1,
#          (76, 67): 1,
#          (162, 83): 1,
#          (90, 54): 1,
#          (376, 274): 1,
#          (1300, 953): 1,
#          (253, 105): 1,
#          (379, 216): 1,
#          (286, 216): 1,
#          (323, 265): 1,
#          (119, 102): 1,
#          (110, 80): 1,
#          (80, 45): 1,
#          (227, 183): 1,
#          (610, 366): 1,
#          (132, 76): 1,
#          (150, 84): 1,
#          (241, 238): 1,
#          (82, 54): 1,
#          (286, 256): 1,
#          (736, 430): 1,
#          (305, 169): 1,
#          (113, 75): 1,
#          (238, 124): 1,
#          (1407, 1244): 1,
#          (113, 72): 1,
#          (159, 87): 1,
#          (327, 190): 1,
#          (422, 190): 1,
#          (100, 84): 1,
#          (171, 130): 1,
#          (211, 217): 1,
#          (260, 128): 1,
#          (1029, 524): 1,
#          (126, 75): 1,
#          (87, 68): 1,
#          (75, 54): 1,
#          (93, 54): 1,
#          (278, 263): 1,
#          (260, 195): 1,
#          (137, 134): 1,
#          (722, 630): 1,
#          (167, 88): 1,
#          (243, 135): 1,
#          (98, 55): 1,
#          (193, 144): 1,
#          (385, 217): 1,
#          (74, 50): 1,
#          (157, 96): 1,
#          (184, 91): 1,
#          (400, 203): 1,
#          (106, 64): 1,
#          (373, 156): 1,
#          (406, 278): 1,
#          (65, 36): 1,
#          (465, 347): 1,
#          (1200, 900): 1,
#          (300, 195): 1,
#          (900, 731): 1,
#          (615, 442): 1,
#          (433, 278): 1,
#          (290, 193): 1,
#          (91, 56): 1,
#          (682, 300): 1,
#          (1000, 657): 1,
#          (1983, 1574): 1,
#          (192, 204): 1,
#          (150, 183): 1,
#          (571, 379): 1,
#          (3700, 2469): 1,
#          (100, 56): 1,
#          (68, 62): 1,
#          (304, 186): 1,
#          (460, 276): 1,
#          (720, 720): 1,
#          (207, 169): 1,
#          (900, 711): 1,
#          (441, 570): 1,
#          (95, 52): 1,
#          (285, 134): 1,
#          (91, 46): 1,
#          (67, 52): 1,
#          (186, 144): 1,
#          (147, 107): 1,
#          (820, 720): 1,
#          (649, 386): 1,
#          (450, 319): 1,
#          (321, 229): 1,
#          (159, 170): 1,
#          (113, 56): 1,
#          (800, 480): 1,
#          (1065, 331): 1,
#          (300, 218): 1,
#          (2200, 733): 1,
#          (340, 288): 1,
#          (493, 315): 1,
#          (269, 241): 1,
#          (400, 267): 1,
#          (650, 221): 1,
#          (1024, 707): 1,
#          (1180, 807): 1,
#          (600, 390): 1,
#          (860, 520): 1,
#          (970, 695): 1,
#          (602, 401): 1,
#          (1000, 694): 1,
#          (1200, 879): 1,
#          (550, 367): 1,
#          (1166, 777): 1,
#          (508, 338): 1,
#          (768, 527): 1,
#          (1125, 750): 1,
#          (1000, 719): 1,
#          (620, 303): 1,
#          (400, 261): 1,
#          (1024, 628): 1,
#          (640, 360): 1,
#          (450, 450): 1,
#          (271, 186): 1,
#          (200, 200): 1,
#          (1314, 864): 1,
#          (300, 279): 1,
#          (682, 392): 1,
#          (400, 272): 1,
#          (1000, 732): 1,
#          (265, 195): 1,
#          (512, 512): 1,
#          (597, 405): 1,
#          (200, 177): 1,
#          (4752, 3168): 1,
#          (260, 178): 1,
#          (6622, 2209): 1,
#          (260, 189): 1,
#          (320, 213): 1,
#          (1903, 575): 1,
#          (154, 115): 1,
#          (900, 600): 1,
#          (900, 623): 1,
#          (500, 280): 1,
#          (494, 337): 1,
#          (768, 768): 1,
#          (323, 242): 1,
#          (1319, 1160): 1,
#          (520, 375): 1,
#          (400, 265): 1,
#          (450, 307): 1,
#          (300, 206): 1,
#          (1600, 1056): 1,
#          (200, 264): 1,
#          (700, 360): 1,
#          (1000, 500): 1,
#          (800, 533): 1,
#          (630, 430): 1,
#          (332, 256): 1,
#          (1024, 541): 1,
#          (800, 521): 1,
#          (186, 134): 1,
#          (5184, 3456): 1,
#          (1100, 619): 1,
#          (258, 177): 1,
#          (642, 403): 1,
#          (2000, 1333): 1,
#          (1167, 875): 1,
#          (400, 400): 1,
#          (829, 626): 1,
#          (400, 250): 1,
#          (400, 275): 1})

# %%
# image size statistics

print('width')
get_stats(all_widths)
print('height')
get_stats(all_heights)
# Out:
# width
# min: 54
# max: 6622
# mean: 761.6
# median: 554
# mode: 1000 (4.9 %)
# height
# min: 36
# max: 3826
# mean: 506.1
# median: 335
# mode: 667 (2.6 %)
