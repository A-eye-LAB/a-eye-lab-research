# %%
import sys

sys.path.append("../")

from analysis_utils import get_all_paths, get_all_image_paths, get_image_w_h, get_stats, count_files, count_formats, count_image_sizes, show_random_image

# %%
root_dir = "../data/Cataract-Detection-and-Classification"

# %%
# count files

all_paths = get_all_paths(root_dir+"/*")
count_files(all_paths)
# Out:
# ../data/Cataract-Detection-and-Classification/0 : 52
# ../data/Cataract-Detection-and-Classification/1 : 80

# %%
# sample image (cataract)
show_random_image(root_dir+"/1")
# Out:
# eye20.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=362x253>

# %%
# sample image (normal)
show_random_image(root_dir+"/0")
# Out:
# normal (67).jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>

# %%
all_image_paths = get_all_image_paths(all_paths)

# %%
# count formats

count_formats(all_image_paths)
# Out:
# Counter({'jpg': 107, 'png': 16, 'jpeg': 9})

# %%
all_widths, all_heights = get_image_w_h(all_image_paths)

# %%
# count image sizes

count_image_sizes(all_widths, all_heights)
# Out:
# Counter({(128, 128): 25,
#          (275, 183): 7,
#          (300, 150): 3,
#          (300, 168): 3,
#          (846, 643): 3,
#          (993, 647): 3,
#          (1111, 680): 2,
#          (48, 46): 2,
#          (124, 119): 2,
#          (259, 194): 2,
#          (289, 307): 2,
#          (250, 188): 2,
#          (2000, 1344): 2,
#          (400, 241): 2,
#          (121, 122): 2,
#          (47, 59): 2,
#          (362, 253): 2,
#          (139, 136): 2,
#          (116, 117): 2,
#          (368, 378): 2,
#          (920, 613): 2,
#          (346, 344): 2,
#          (725, 735): 2,
#          (999, 650): 2,
#          (111, 115): 2,
#          (49, 46): 2,
#          (413, 304): 1,
#          (39, 38): 1,
#          (800, 534): 1,
#          (556, 368): 1,
#          (2048, 1536): 1,
#          (85, 97): 1,
#          (1461, 1071): 1,
#          (580, 447): 1,
#          (1000, 591): 1,
#          (38, 37): 1,
#          (306, 165): 1,
#          (1320, 837): 1,
# ...

# %%
# image size statistics

print('width')
get_stats(all_widths)
print('height')
get_stats(all_heights)
# Out:
# width
# min: 38
# max: 2048
# mean: 445.4
# median: 278
# mode: 128 (18.9 %)
# height
# min: 37
# max: 1632
# mean: 320.1
# median: 183
# mode: 128 (18.9 %)
